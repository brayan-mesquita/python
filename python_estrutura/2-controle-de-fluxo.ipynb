# %%
print('True' == True)#falso
print('False' == 'True')#falso
print(not'False' == 'True')#verdadeiro
print('False' == 'False')#verdadeiro
print(True == False)
print(1 == int('1'))#verdadeiro
print(1 == 1)#verdadeiro
print(1 != 2)#verdadeiro
# Out:
# False
# False
# True
# True
# False
# True
# True
# True

# %%
um, n1, dois, n2 = 1, '1', 2, '2'
print(f"{um==um},{um!=dois},{um==int(n1)}")
listaBooleana = []
listaBooleana.append([um==um,um!=um,dois==int(n2)])
print(listaBooleana)
# Out:
# True,True,True
# [[True, False, True]]

# %% [markdown]
# ## Condição if e elif

# %%
senha, usuario = 123, "Maria"
login = input("Digite seu nome de usuario: ")
if login == usuario:
  print(f"Ola {usuario}")
  password = input("Digite sua senha: ")
  if int(password) == senha:
    print("Logado com sucesso!")
  else:
    print("Senha errada")
else:
  print("Voce não esta autorizado")
# Out:
# Digite seu nome de usuario: Maria
# Ola Maria
# Digite sua senha: 123
# Logado com sucesso!

# %%
nome, idade = "Brayan", 30
if nome == "Brayan" and idade == 30:
  print(f"Ola {nome}")
elif idade != 30:
  print("Você nao tem 30")
else:
  print("Voce nao e Brayan")
# Out:
# Ola Brayan

# %%
#todas as condições verdadeiras são alcançadas
numero = 5
if numero > 0:
  print(f"O numéro {numero} é maior que 0")
if numero >= 5:
  print(f"O numéro {numero} é maior ou igual a 5")
# Out:
# O numéro 5 é maior que 0
# O numéro 5 é maior ou igual a 5

# %% [markdown]
# #Condição while

# %%
spam = 0
while spam < 10: 
  print('Hello, world.') 
  spam = spam + 1
# Out:
# Hello, world.
# Hello, world.
# Hello, world.
# Hello, world.
# Hello, world.

# %%
name = "Brayan Soares"
n = 0
while n != len(name):
  print(name[n].capitalize())
  n += 1

# %% [markdown]
# ##break
#
# As instruções break e as instruções continue são usadas dentro de loops

# %%
nome = "Brayan"
alguem = ""
while nome != alguem:
  alguem = input("Seu nome: ")
  if nome != alguem:
    print("Tente novamente!")
  if alguem == "naosei":
    break
print(f"Ola, {alguem}")
# Out:
# Seu nome: Brayan
# Ola, Brayan

# %%
while True:
  nome = input('Seu nome! ')
  if nome ==  'miguel':
    print('ola, miguel!')
    break

# %% [markdown]
# ##continue

# %%
while True:
  nome = input("Seu nome? ")
  if nome != "Brayan":
    continue
  print(f"Olá {nome}")
  senha = input("Qual a senha?")
  if senha != "123":
    continue
  break
# Out:
# Seu nome? Brayan
# Olá Brayan
# Qual a senha?4
# Seu nome? Brayan
# Olá Brayan
# Qual a senha?123

# %%
n = 0
while True:
  if (n % 4) == 0 and n != 0:
    print(f"O numero {n} é divisivel por 4, sendo o resultado: {int(n/4)}.")
  n += 1
  if n == 50:
    break
# Out:
# O numero 4 é divisivel por 4, sendo o resultado: 1.
# O numero 8 é divisivel por 4, sendo o resultado: 2.
# O numero 12 é divisivel por 4, sendo o resultado: 3.
# O numero 16 é divisivel por 4, sendo o resultado: 4.
# O numero 20 é divisivel por 4, sendo o resultado: 5.
# O numero 24 é divisivel por 4, sendo o resultado: 6.
# O numero 28 é divisivel por 4, sendo o resultado: 7.
# O numero 32 é divisivel por 4, sendo o resultado: 8.
# O numero 36 é divisivel por 4, sendo o resultado: 9.
# O numero 40 é divisivel por 4, sendo o resultado: 10.
# O numero 44 é divisivel por 4, sendo o resultado: 11.
# O numero 48 é divisivel por 4, sendo o resultado: 12.

# %% [markdown]
# ##range

# %%
vezes = 5
for i in range(vezes):
  print(f'Contagem até {vezes} (' + str(i) + ')')
# Out:
# Contagem até 5 (0)
# Contagem até 5 (1)
# Contagem até 5 (2)
# Contagem até 5 (3)
# Contagem até 5 (4)

# %%
for x in range(0, 20, 5):
  print(x)
# Out:
# 0
# 5
# 10
# 15

# %%
for w in reversed(range(2, 11, 2)):
  print(w)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
for i in range(5, -1, -1):
  print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
n = 5
lista = []
for i in range(n):
  lista.append(i)
for i in lista:
  print(f'{n} x {i} = {n * i}')
# Out:
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20

# %%
n = 5
for i in range(n):
  print(f'{n}x{i}={n*i}')
# Out:
# 5x0=0
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20

# %% [markdown]
# #Encenrrando execução

# %% [markdown]
# ##sys.exit()
# terminando um programa antecipadamente com sys.exit() O último conceito de controle de fluxo a ser abordado é como encerrar o programa. Isso sempre acontece se a execução do programa atingir o final das instruções

# %%
import sys
while True:
  print('Type exit to exit.')
  response = input()
  if response == 'exit':
    sys.exit()
  print('You typed ' + response + '.')

# %% [markdown]
# #Operadores Booleanos

# %% [markdown]
# O computador avaliará primeiro a expressão da esquerda e, em seguida, avaliará a expressão da direita. Quando souber o valor booleano de cada um, ele avaliará toda a expressão até um valor booleano

# %%
print((5>3) and (6>8) or (5 == 5)) #verdadeiro
print((5>3) and ((6>8) or (5 != 5))) #falso
print(False and True)#falso
print(True or not(False and True))#verdadeiro
print(not True)#falso

# %%
2 + 2 == 4 and not 2 + 2 == 5 and 2 * 2 == 2 + 2
# Out:
# True

# %%
a = True
b = 'valor qualquer'
c = ""
d = False

if (c):
    print(b)

# %% [markdown]
# Automatize as coisa chatas com python
# pagina 51
