# %% [markdown]
# # VARIÁVEIS

# %% [markdown]
# ## Declarando variáveis

# %%
#FORMA RESUMIDA DE DELCARAR VARIÁVEIS
nome, idade, altura, sexo, hobs = 'Brayan', 28, 1.72, 'masculino', ['programação', 'música', 'capoeira']

# %%
#IMPRINDO VARIÁVEIS COM F STRINGS
print(f'Meu nome é {nome}, tenho {idade} anos, a altura de {altura}, meu sexo é {sexo} e tenho como hobs: {hobs}.')
# Out:
# Meu nome é Brayan, tenho 28 anos, a altura de 1.72, meu sexo é masculino e tenho como hobs: ['programação', 'música', 'capoeira'].

# %%
variavel_1 = 1
print(variavel_1)
variavel_2 = variavel_1 + 1
print(variavel_2)
variavel_1 *= 3
print(variavel_1)
variavel_2 /= 0.5
print(int(variavel_2))
variavel_2 %= 4
print(variavel_2)
# Out:
# 1
# 2
# 3
# 4
# 0.0

# %%
#IMPRIMINDO TODOS OS ÍNDICES E VALORES DA LISTA DE HOBS
print('Índice:', *range(len(hobs)))
print('Índice:', *hobs)
# Out:
# Índice: 0 1 2
# Índice: programação música capoeira

# %%
#DECLARANDO UM VALOR PARA VÁRIAS VARIÁVEIS
n1 = n2 = n3 = 28
print(f'{n1}, {n2}, {n3}')
# Out:
# 28, 28, 28

# %% [markdown]
# ## Tipos de Variáveis

# %%
a = 'Brayan'
b = 2 
c = 1.25
d = ['computer', 'celular', 'violão']
e = {'Carros':['Fusca', 'Onix', 'Corcel'], 'Motos':['Fan 160', 'Biz 125', 'Pop 100']}
f = ('nao modifica', 'imutáveis', 'são as tuplas') 
g = True
lista = [a, b, c, d, e, f, g]

# %%
for x in lista:
  print(type(x))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'dict'>
# <class 'tuple'>
# <class 'bool'>

# %%
#IMPRIMINDO OS VALORES DAS VARIÁVEIS
for variavel in lista:
  print(f"{variavel} é do tipo: {type(variavel)}")
# Out:
# Brayan é do tipo: <class 'str'>
# 2 é do tipo: <class 'int'>
# 1.25 é do tipo: <class 'float'>
# ['computer', 'celular', 'violão'] é do tipo: <class 'list'>
# {'Carros': ['Fusca', 'Onix', 'Corcel'], 'Motos': ['Fan 160', 'Biz 125', 'Pop 100']} é do tipo: <class 'dict'>
# ('nao modifica', 'imutáveis', 'são as tuplas') é do tipo: <class 'tuple'>
# True é do tipo: <class 'bool'>

# %% [markdown]
# ## Concatenação

# %%
a = 'brayan'
b = 'soares'
espaco = ' '
c = a + espaco + b
c
# Out:
# 'brayan soares'

# %% [markdown]
# # OPERADORES
#
# - São simbolos especiais que representam operações em matemática.

# %%
somar = lambda a,b: a + b
subtrair = lambda a,b: a - b
multiplicar = lambda a,b: a * b
dividir = lambda a,b: a / b
dividir_int = lambda a, b: a // b
modulo = lambda a,b: a % b
exponenciacao =lambda a,b: a ** b


operadores = [somar, subtrair, multiplicar, dividir, dividir_int, modulo, exponenciacao]

for x in operadores:
  print(x(3,2))
# Out:
# 5
# 1
# 6
# 1.5
# 1
# 1
# 9

# %% [markdown]
# - existem ainda os operadores booleanos e lógicos a serem estudados a seguir

# %% [markdown]
# # DICIONÁRIOS

# %%
#CRIANDO DICIONÁRIOS
dicionario = {'Carros':'Fusca', 
              'Motos':['Fan 160', ['bmw g310', 'Yamaha  MT 09']], 
              1: 'Qualquer'}

# %%
#RETORNANDO ELEMENTOS ITENS
print(dicionario['Carros'])
print(dicionario.get('Motos'))
print(dicionario['Motos'][1][1])
print(dicionario.get(1))
# Out:
# Fusca
# ['Fan 160', ['bmw g310', 'Yamaha  MT 09']]
# Yamaha  MT 09
# Qualquer

# %%
#ATULIZANDO ITENS
dicionario['Carros'] = 'Onix'
dicionario['Motos'][0], dicionario['Motos'][1][1] = 'Brós 150', 'Falcon'
dicionario.update({1:'Brayan'})
print(dicionario)
# Out:
# {'Carros': 'Onix', 'Motos': ['Brós 150', ['bmw g310', 'Falcon']], 1: 'Brayan'}

# %% [markdown]
# ## Converter lista em dicionário

# %%
#CONVERTENDO LISTA EM DICIONÁRIO
contatos_lista = [('Yan', '1234-5678'), ('Pedro', '9999-9999'),
                    ('Ana', '8765-4321'), ('Marina', '8877-7788')]
print(f'{type(contatos_lista)} {contatos_lista}')

print('\t')
#UTLIZANDO FUNÇÃO 'dict'
contatos_dicio = dict(contatos_lista)
print(f'{type(contatos_dicio)} {contatos_dicio}')

print('\t')
#IMPRIMINDO CHAVES
print(contatos_dicio.keys())

print('\t')
#IMPRIMINDO VALORES
print(contatos_dicio.values())
# Out:
# <class 'list'> [('Yan', '1234-5678'), ('Pedro', '9999-9999'), ('Ana', '8765-4321'), ('Marina', '8877-7788')]
#
# <class 'dict'> {'Yan': '1234-5678', 'Pedro': '9999-9999', 'Ana': '8765-4321', 'Marina': '8877-7788'}
#
# dict_keys(['Yan', 'Pedro', 'Ana', 'Marina'])
#
# dict_values(['1234-5678', '9999-9999', '8765-4321', '8877-7788'])

# %% [markdown]
# # LISTAS

# %% [markdown]
# [FONTE DE ESTUDO](https://panda.ime.usp.br/pensepy/static/pensepy/09-Listas/listas.html)
#
# [FONTE 2](https://algoritmosempython.com.br/cursos/programacao-python/listas/)

# %%
#CRIANDO LISTAS
vazia = []
varios = [10, 20, 30, 40, 'meu nome é Brayan', True, 3.12]
veiculos = ["Carro", "Moto", "Aeronave"]
diversos = ['João',{'Idade':28}, ['Música', 'Esporte']]
lista_das_listas = [vazia, varios, veiculos, diversos]

# %%
#RETORNANDO VALORES DE LISTAS
print(diversos[1]['Idade'])
print(varios[4-3])
print(varios[-2])
print(varios[len(varios)-2])
print(varios[4].upper())
print(float(varios[1]))
print(len(lista_das_listas))
print(lista_das_listas)
# Out:
# 28
# 20
# True
# True
# MEU NOME É BRAYAN
# 20.0
# 4
# [[], [10, 20, 30, 40, 'meu nome é Brayan', True, 3.12], ['Carro', 'Moto', 'Aeronave'], ['João', {'Idade': 28}, ['Música', 'Esporte']]]

# %% [markdown]
# #TUPLAS

# %%
tuple1 = (1, 3, [2, 4]) #pode conter listas
tuple2 = 5, 6, 7 #outra forma de descrever uma tupla
print(f'{tuple1} e {tuple2}')
# Out:
# (1, 3, [2, 4]) e (5, 6, 7)

# %% [markdown]
# # CONJUNTOS

# %%
c = set()
c.add(1)
c.add(2)
x = len(c)
y = 2 in c
z = 0 in c
print(x, y, z)
# Out:
# 2 True False

# %% [markdown]
# # FUNÇÕES BULT IN

# %% [markdown]
# # CONDICIONAIS

# %% [markdown]
# ## Expressões booleanas
# - são expressões que podem ser verdadeiras ou falsas

# %%
print(5 == '5') # false
print(2 == 2.0) # true
print(1 is 2) # false
print(0 is 0) # true
print('a' is not 'b') # true
print(0 is not 0) # false
print (5 >= 5) # true
print(2 != 2) # false
# Out:
# False
# True
# False
# True
# True
# False
# True
# False
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-20-4b65c0212957>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(1 is 2) # false
# <ipython-input-20-4b65c0212957>:4: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(0 is 0) # true
# <ipython-input-20-4b65c0212957>:5: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   print('a' is not 'b') # true
# ...

# %% [markdown]
# ##Operadores Lógicos

# %% [markdown]
# # LOOPS

# %% [markdown]
# ## While

# %%
x = 0
while x < 10:
  print(x, 'menor que 10')
  x += 1
# Out:
# 0 menor que 10
# 1 menor que 10
# 2 menor que 10
# 3 menor que 10
# 4 menor que 10
# 5 menor que 10
# 6 menor que 10
# 7 menor que 10
# 8 menor que 10
# 9 menor que 10

# %% [markdown]
# ## For

# %%
#Range
for y in range(5):
  print(y)

print('\n')

for x in range(0, 20, 5):
  print(x)

print('\n')

for w in reversed(range(2, 11, 2)):
  print(w)
# Out:
# 0
# 1
# 2
# 3
# 4
#
#
# 0
# 5
# 10
# 15
#
#
# 10
# 8
# 6
# 4
# 2
