# %%
from collections import defaultdict

# %%
c = dict(zip(['one', 'two', 'three'], [1, 2, 3]))
d = dict(zip(['one', 'two', 'three', 'for, five, six'], [1, 2, 3,[4, 5, 6]]))

# %%
arestas = [('A', 'B', 1.0), ('A', 'C'), ('C', 'A'), ('B', 'D')]
type(arestas[0][2])
# Out:
# float
