# %%
from modulos.funcoes import somar, subtrair
subtrair(5, 6)
# Out:
# -1

# %%
class Pessoa():
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade
        self._protegido = ["protegido", "protegido_final"] #acesivel por dentro e fora da classe, identificado algo importante que nao deve ser alterado
        self.__privado = ["privado"] #nao acessivel por fora, apenas por funcao ou return, e praticamente imutavel
        self.a = 1
        self.b = 2
    def dizer(self):
        return self.__privado[-1], self._protegido[-1], self.a + self.b

brayan = Pessoa("brayan", 20)
brayan.dizer()
# Out:
# ('privado', 'protegido_final', 3)

# %%
property()
property.setter
# Out:
# <method 'setter' of 'property' objects>

# %%
lista = 'https://diof.ro.gov.br/data/uploads/2022/10/DOE-25.10.2022.pdf'
RETA = '-'
chave = RETA.join(lista[-14:-4].split('.'))
chave
# Out:
# '25-10-2022'

# %%
dicionario = {'31-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/DOE-31.10.2022.pdf',
 '28-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/Doe-Suplementar-28-10-2022.pdf',
 '10-2022-02': 'https://diof.ro.gov.br/data/uploads/2022/10/Doe-Suplementar-28-10-2022-02.pdf',
 '27-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/DOE-27.10.2022.pdf',
 '26-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/Doe-Suplementar-26-10-2022.pdf',
 '25-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/Doe-Suplementar-25-10-2022.pdf',
 '24-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/Doe-suplementar-24-10-2022.pdf',
 '21-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/DOE-SUPLEMENTAR-21.10.2022.pdf',
 '20-10-2022': 'https://diof.ro.gov.br/data/uploads/2022/10/DOE-20.10.2022.pdf'}

# %%
dicionario.keys()
# Out:
# dict_keys(['31-10-2022', '28-10-2022', '10-2022-02', '27-10-2022', '26-10-2022', '25-10-2022', '24-10-2022', '21-10-2022', '20-10-2022'])

# %% [markdown]
# ## Associação de classes

# %%
class Usuario:
    def __init__(self, nome):
        self.__nome = nome
        self.__logar = None
    @property
    def nome(self):
        return self.__nome
    @property
    def logar(self):
        return self.__logar
    @logar.setter
    def logar(self, logar):
        self.__logar = logar

class Identificador:
    def __init__(self, numero):
        self.__numero = numero
    @property
    def numero(self):
        return self.__numero
    def logar(self):
        print('Logando no sistema..')
    def teste(self):
        print('imprimir identificador')

usuario = Usuario('Brayan')
identificador = Identificador('0001')
usuario.logar = identificador#a classe identificador esta na funcao logar da classe usuario
usuario.logar.logar()
# Out:
# Logando no sistema..

# %%
# Out:
# imprimir identificador
