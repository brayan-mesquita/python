# %% [markdown]
# ##dizer nome

# %%
def oi_Alguem(nome):
  print(f'Oi {nome}, tudo bem?')
nome = input('Digite seu nome: ')
oi_Alguem(nome)
# Out:
# Digite seu nome: Brayan
# Oi Brayan, tudo bem?

# %% [markdown]
# ##contar até

# %%
#contar de 0 até o numero que for digitado
def contar_Ate(numero):
  for i in range(0, numero+1):
    print(i)
contar_Ate(10)

# %% [markdown]
# ##imprimir frase x vezes

# %%
def imprirmir_x(frase, vezes):
  retorno = (frase + ' ') * vezes
  return retorno
imprirmir_x("Brayan", 100)
# Out:
# 'Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan Brayan '

# %%
def dividir(n, d=0):
  try: 
    print(int(n/d))
  except:
    print('O numero nao pode ser dividido por 0')
dividir(10)
dividir(10, 5)
# Out:
# O numero nao pode ser dividido por 0
# 2

# %% [markdown]
# ##print

# %%
print('ola', end=' ')
print('oi')
# Out:
# ola oi

# %%
print('casa', 'cachorro', 'bibicleta', sep=', ', end='|')
print('casa', 'cachorro', 'bibicleta', sep=', ')
# Out:
# casa, cachorro, bibicleta|casa, cachorro, bibicleta

# %% [markdown]
# #escopo de funcoes

# %%
def spam():
  eggs = 99
  bacon()
  print(eggs)
def bacon():
  ham = 101
  eggs = 0  
spam()
# Out:
# 99

# %%
nome = 'miguel'
def escopo():
  nome = 'brayan'
  print('ola', nome)
escopo()
print(nome)
# Out:
# ola brayan
# miguel

# %%
def escopo():
  zzz = 'miguel'
escopo()
print(zzz)

# %%
def spam():
  global eggs
  eggs = 'spam'
eggs = 'global'
print(eggs, end=' ')
spam()
print(eggs)
# Out:
# global spam

# %% [markdown]
# #adivinhação

# %%
import random
secretNumber = random.randint(1, 20)
print('Adivinhe o numero entre 1 e 20')
# Ask the player to guess 6 times.
for guessesTaken in range(1, 7):
 print('Acho que é.')
 guess = int(input())
 if guess < secretNumber:
  print('É maior')
 elif guess > secretNumber:
  print('é menor')
 else:
  break # This condition is the correct guess!
if guess == secretNumber:
 print('acertou ' + str(guessesTaken) + ' palpite!')
else:
 print('errou ' + str(secretNumber))

# %% [markdown]
# ##args e kwargs

# %%
def printar(*args):
    for i in args:
        print(i)
printar('brayan', 'miguel', 'sophia')
# Out:
# brayan
# miguel
# sophia

# %%
def falardescricao(**kwargs):
    for i, y in kwargs.items():
        print(i + ":" + y)
cientista = falardescricao(nome='brayan', idade='30', estadocivil='casado')
print(cientista)
# Out:
# nome:brayan
# idade:30
# estadocivil:casado
# None
